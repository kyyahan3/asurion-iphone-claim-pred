# %% [markdown]
# # XGBoost Model: Storage Feature Set

# %% [markdown]
# ## This is the XGBoost model with the storage feature set, i.e. including storage size, but not color in the features used.

# %% [markdown]
# In this notebook, we'll be implementing an xgBoost model on our data.
# XGBoost, which stands for Extreme Gradient Boosting, is a scalable, distributed gradient-boosted decision tree (GBDT) machine learning library. It provides parallel tree boosting and is the leading machine learning library for regression, classification, and ranking problems.

# %% [markdown]
# Documentation on xbgoost can be found here: https://xgboost.readthedocs.io/en/stable/tutorials/model.html

# %%
#load in needed packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import xgboost as xgb 
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Load in data

# %% [markdown]
# The data we are loading in is the cleaned version of all of the data given by the client, including the additional data for February and March we were provided. These extra data points were added to the testing data set.

# %%
#%cd ../../../../data/p_dsi/teams2023/team1

# %%
#read in full data from xlsx file
df = pd.read_excel("full_data_clean.xlsx" )
df
# Out:
#       Unnamed: 0          phone model phone size phone color  claim  \
# 0           3059      apple iphone 12      128gb       black     14
# 1           3060      apple iphone 12      128gb       black     43
# 2           3061      apple iphone 12      128gb       black     57
# 3           3062      apple iphone 12      128gb       black     65
# 4           3063      apple iphone 12      128gb       black     59
# ...          ...                  ...        ...         ...    ...
# 1273        7964  apple iphone 14 pro      128gb      silver      4
# 1274        7966  apple iphone 14 pro      256gb       black     33
# 1275        7968  apple iphone 14 pro      256gb        gold      2
# 1276        7970  apple iphone 14 pro      256gb      purple     39
# 1277        7972  apple iphone 14 pro      256gb      silver      1
#
#      weeks_monday  brand   model  generation  week_of_month  month  year  \
# 0      2021-08-02  apple  iphone          12              1      8  2021
# 1      2021-08-09  apple  iphone          12              2      8  2021
# 2      2021-08-16  apple  iphone          12              3      8  2021
# 3      2021-08-23  apple  iphone          12              4      8  2021
# 4      2021-08-30  apple  iphone          12              5      8  2021
# ...           ...    ...     ...         ...            ...    ...   ...
# 1273   2023-02-13  apple  iphone          14              2      2  2023
# 1274   2023-02-27  apple  iphone          14              4      2  2023
# 1275   2023-02-27  apple  iphone          14              4      2  2023
# 1276   2023-02-27  apple  iphone          14              4      2  2023
# 1277   2023-02-27  apple  iphone          14              4      2  2023
#
#         release  weeks_since_release  is_holiday
# 0    2020-11-13            37.428571           1
# 1    2020-11-13            38.428571           1
# 2    2020-11-13            39.428571           1
# 3    2020-11-13            40.428571           1
# 4    2020-11-13            41.428571           1
# ...         ...                  ...         ...
# 1273 2022-09-16            21.428571           0
# 1274 2022-09-16            23.428571           0
# 1275 2022-09-16            23.428571           0
# 1276 2022-09-16            23.428571           0
# 1277 2022-09-16            23.428571           0
#
# [1278 rows x 15 columns]

# %%
#load in data for testing and training the model 
train = pd.read_excel("train_data_final.xlsx" )
test = pd.read_excel("test_data_final.xlsx" )

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# First, we'll drop features we don't need in our data.

# %%
#drop phone model (we know the phone model based on the generation of the phone)
train = train.drop(['phone model'], axis=1)

test = test.drop(['phone model'], axis=1)

# %%
#drop is_holiday
train = train.drop(['is_holiday'], axis=1)
test = test.drop(['is_holiday'], axis=1)

# %%
#drop unamed: 0 from train data (this is the index column)
train = train.drop(['Unnamed: 0'], axis=1)
test = test.drop(['Unnamed: 0'], axis=1)

# %%
#drop phone color (not included in this feature set)
test = test.drop(['phone color'], axis=1)
train = train.drop(['phone color'], axis=1)

# %%
#examine the data to make sure it is correct
train.head(10)
# Out:
#    phone size  claim weeks_monday  generation  week_of_month  month  year  \
# 0         128     14   2021-08-02          12              1      8  2021
# 1         128     43   2021-08-09          12              2      8  2021
# 2         128     57   2021-08-16          12              3      8  2021
# 3         128     65   2021-08-23          12              4      8  2021
# 4         128     59   2021-08-30          12              5      8  2021
# 5         128     45   2021-09-06          12              1      9  2021
# 6         128     49   2021-09-13          12              2      9  2021
# 7         128     54   2021-09-20          12              3      9  2021
# 8         128     62   2021-09-27          12              4      9  2021
# 9         128     65   2021-10-04          12              1     10  2021
#
#    weeks_since_release  day
# 0            37.428571    2
# 1            38.428571    9
# 2            39.428571   16
# 3            40.428571   23
# 4            41.428571   30
# 5            42.428571    6
# 6            43.428571   13
# 7            44.428571   20
# 8            45.428571   27
# 9            46.428571    4

# %% [markdown]
# ## Examine phone trends before modeling

# %% [markdown]
# Plot a time series graph for the iPhone 12, 13, and 14 based on their release and generation

# %%
# Filter data for iPhones 12, 13, and 14
selected_iphones = df[df['generation'].isin([12, 13, 14])]
selected_iphones = selected_iphones[['claim', 'weeks_since_release', 'weeks_monday', 'generation']]

# Group by weeks_monday and generation, sum up all the claims
grouped_data = selected_iphones.groupby(['weeks_monday', 'generation']).agg({'claim': 'sum'}).reset_index()

# Pivot the table to have generations as columns
pivot_data = grouped_data.pivot_table(index='weeks_monday', columns='generation', values='claim', fill_value=0).reset_index()


import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
for gen in [12, 13, 14]:
    # Filter out rows with zero claims
    filtered_data = pivot_data[pivot_data[gen] > 0]
    
    plt.plot(filtered_data['weeks_monday'], filtered_data[gen], label=f"iPhone {gen}", marker='o')

plt.xlabel("Time")
plt.ylabel("Claim Volumes")
plt.title("Time Series of Claim Volumes for iPhone 12, 13, and 14")
plt.legend()
plt.show()

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Create training and testing set

# %%
#for dataset that has time series, set the datetime value as the index variable
# set week_of_month as index

#set the index of the training data to be the weeks_monday
train = train.set_index("weeks_monday")
train.head()
# Out:
#               phone size  claim  generation  week_of_month  month  year  \
# weeks_monday
# 2021-08-02           128     14          12              1      8  2021
# 2021-08-09           128     43          12              2      8  2021
# 2021-08-16           128     57          12              3      8  2021
# 2021-08-23           128     65          12              4      8  2021
# 2021-08-30           128     59          12              5      8  2021
#
#               weeks_since_release  day
# weeks_monday
# 2021-08-02              37.428571    2
# 2021-08-09              38.428571    9
# 2021-08-16              39.428571   16
# 2021-08-23              40.428571   23
# 2021-08-30              41.428571   30

# %%
#set the index of the testing data to be the weeks_monday
test = test.set_index("weeks_monday")

#drop index column from testing data
#test = test.drop(['index'], axis=1)

# %%
test.head(15)
# Out:
#               phone size  claim  generation  week_of_month  month  year  \
# weeks_monday
# 2022-12-19           128     20          14              3     12  2022
# 2022-12-26           128     23          14              4     12  2022
# 2023-01-02           128     28          14              1      1  2023
# 2023-01-09           128     37          14              2      1  2023
# 2023-01-16           128     35          14              3      1  2023
# 2023-01-23           128     39          14              4      1  2023
# 2023-01-30           128     33          14              5      1  2023
# 2022-12-19           128      8          14              3     12  2022
# 2022-12-26           128      5          14              4     12  2022
# 2023-01-02           128      5          14              1      1  2023
# 2023-01-09           128      6          14              2      1  2023
# 2023-01-16           128     11          14              3      1  2023
# 2023-01-23           128      8          14              4      1  2023
# 2023-01-30           128      6          14              5      1  2023
# 2022-12-19           256      4          14              3     12  2022
#
#               weeks_since_release  day
# weeks_monday
# 2022-12-19              13.428571   19
# 2022-12-26              14.428571   26
# 2023-01-02              15.428571    2
# 2023-01-09              16.428571    9
# 2023-01-16              17.428571   16
# 2023-01-23              18.428571   23
# 2023-01-30              19.428571   30
# 2022-12-19              13.428571   19
# 2022-12-26              14.428571   26
# 2023-01-02              15.428571    2
# 2023-01-09              16.428571    9
# 2023-01-16              17.428571   16
# 2023-01-23              18.428571   23
# 2023-01-30              19.428571   30
# 2022-12-19              13.428571   19

# %% [markdown]
# #### Set x,y train and test

# %%
#set x,y train and test

x_train = train.drop('claim', axis=1)
y_train = train['claim']

x_test = test.drop('claim', axis=1)
y_test = test['claim']

x_train.shape, y_train.shape
# Out:
# ((1205, 7), (1205,))

# %% [markdown]
# ### Fit the Model

# %%
model = xgb.XGBRegressor(base_score =0.2, booster='gbtree', n_estimators =1000,
                        objective = 'reg:linear', max_depth =5, learning_rate=0.01)

model.fit(x_train, y_train, 
           eval_set = [(x_train, y_train), (x_test, y_test)] )
# Out:
# [22:00:26] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:84.79954	validation_1-rmse:38.38298
# [1]	validation_0-rmse:84.37980	validation_1-rmse:38.24819
# [2]	validation_0-rmse:83.96634	validation_1-rmse:38.11512
# [3]	validation_0-rmse:83.55908	validation_1-rmse:37.98373
# [4]	validation_0-rmse:83.15794	validation_1-rmse:37.85402
# [5]	validation_0-rmse:82.76287	validation_1-rmse:37.72596
# [6]	validation_0-rmse:82.37377	validation_1-rmse:37.59953
# [7]	validation_0-rmse:81.99059	validation_1-rmse:37.47465
# [8]	validation_0-rmse:81.61325	validation_1-rmse:37.35141
# [9]	validation_0-rmse:81.24168	validation_1-rmse:37.22979
# [10]	validation_0-rmse:80.87581	validation_1-rmse:37.10976
# [11]	validation_0-rmse:80.51557	validation_1-rmse:36.99143
# [12]	validation_0-rmse:80.16090	validation_1-rmse:36.87466
# [13]	validation_0-rmse:79.81171	validation_1-rmse:36.75931
# [14]	validation_0-rmse:79.46795	validation_1-rmse:36.64559
# [15]	validation_0-rmse:79.12955	validation_1-rmse:36.53338
# [16]	validation_0-rmse:78.79643	validation_1-rmse:36.42266
# [17]	validation_0-rmse:78.46853	validation_1-rmse:36.31340
# [18]	validation_0-rmse:78.14580	validation_1-rmse:36.20546
# [19]	validation_0-rmse:77.82815	validation_1-rmse:36.12575
# [20]	validation_0-rmse:77.51552	validation_1-rmse:36.04715
# [21]	validation_0-rmse:77.20770	validation_1-rmse:35.95954
# [22]	validation_0-rmse:76.90493	validation_1-rmse:35.88319
# [23]	validation_0-rmse:76.60698	validation_1-rmse:35.78227
# [24]	validation_0-rmse:76.31364	validation_1-rmse:35.70116
# [25]	validation_0-rmse:76.02499	validation_1-rmse:35.62119
# [26]	validation_0-rmse:75.74098	validation_1-rmse:35.54236
# [27]	validation_0-rmse:75.46154	validation_1-rmse:35.46225
# [28]	validation_0-rmse:75.18674	validation_1-rmse:35.39259
# [29]	validation_0-rmse:74.91624	validation_1-rmse:35.31726
# [30]	validation_0-rmse:74.65030	validation_1-rmse:35.24440
# [31]	validation_0-rmse:74.38869	validation_1-rmse:35.17257
# [32]	validation_0-rmse:74.13134	validation_1-rmse:35.10175
# [33]	validation_0-rmse:73.87819	validation_1-rmse:35.03193
# [34]	validation_0-rmse:73.62918	validation_1-rmse:34.96310
# [35]	validation_0-rmse:73.38426	validation_1-rmse:34.89524
# [36]	validation_0-rmse:73.14337	validation_1-rmse:34.82833
# [37]	validation_0-rmse:72.90644	validation_1-rmse:34.76238
# [38]	validation_0-rmse:72.67344	validation_1-rmse:34.69736
# [39]	validation_0-rmse:72.44398	validation_1-rmse:34.61520
# [40]	validation_0-rmse:72.21859	validation_1-rmse:34.55231
# [41]	validation_0-rmse:71.99696	validation_1-rmse:34.49017
# [42]	validation_0-rmse:71.77902	validation_1-rmse:34.42797
# [43]	validation_0-rmse:71.56472	validation_1-rmse:34.36760
# [44]	validation_0-rmse:71.35401	validation_1-rmse:34.30810
# [45]	validation_0-rmse:71.14645	validation_1-rmse:34.23201
# [46]	validation_0-rmse:70.94274	validation_1-rmse:34.17449
# [47]	validation_0-rmse:70.74246	validation_1-rmse:34.11779
# [48]	validation_0-rmse:70.54501	validation_1-rmse:34.06102
# [49]	validation_0-rmse:70.35090	validation_1-rmse:34.00596
# [50]	validation_0-rmse:70.16009	validation_1-rmse:33.95168
# [51]	validation_0-rmse:69.97262	validation_1-rmse:33.88120
# [52]	validation_0-rmse:69.78823	validation_1-rmse:33.82599
# [53]	validation_0-rmse:69.60700	validation_1-rmse:33.77153
# [54]	validation_0-rmse:69.42886	validation_1-rmse:33.71783
# [55]	validation_0-rmse:69.25377	validation_1-rmse:33.66403
# [56]	validation_0-rmse:69.08170	validation_1-rmse:33.61179
# [57]	validation_0-rmse:68.91261	validation_1-rmse:33.54632
# [58]	validation_0-rmse:68.74640	validation_1-rmse:33.49581
# [59]	validation_0-rmse:68.58306	validation_1-rmse:33.44599
# [60]	validation_0-rmse:68.42254	validation_1-rmse:33.39687
# [61]	validation_0-rmse:68.26481	validation_1-rmse:33.34842
# [62]	validation_0-rmse:68.10982	validation_1-rmse:33.30064
# [63]	validation_0-rmse:67.95752	validation_1-rmse:33.25274
# [64]	validation_0-rmse:67.80782	validation_1-rmse:33.19714
# [65]	validation_0-rmse:67.66077	validation_1-rmse:33.15083
# [66]	validation_0-rmse:67.51668	validation_1-rmse:33.10825
# [67]	validation_0-rmse:67.37472	validation_1-rmse:33.06392
# [68]	validation_0-rmse:67.23526	validation_1-rmse:33.02019
# [69]	validation_0-rmse:67.09817	validation_1-rmse:32.96403
# [70]	validation_0-rmse:66.96392	validation_1-rmse:32.92154
# [71]	validation_0-rmse:66.83166	validation_1-rmse:32.87982
# [72]	validation_0-rmse:66.70211	validation_1-rmse:32.83918
# [73]	validation_0-rmse:66.57441	validation_1-rmse:32.78978
# [74]	validation_0-rmse:66.44903	validation_1-rmse:32.74927
# [75]	validation_0-rmse:66.32587	validation_1-rmse:32.70999
# [76]	validation_0-rmse:66.20525	validation_1-rmse:32.67125
# [77]	validation_0-rmse:66.08642	validation_1-rmse:32.63239
# [78]	validation_0-rmse:65.97006	validation_1-rmse:32.59515
# [79]	validation_0-rmse:65.85547	validation_1-rmse:32.51618
# [80]	validation_0-rmse:65.74287	validation_1-rmse:32.47757
# [81]	validation_0-rmse:65.63230	validation_1-rmse:32.43949
# [82]	validation_0-rmse:65.52361	validation_1-rmse:32.39555
# [83]	validation_0-rmse:65.41728	validation_1-rmse:32.35870
# [84]	validation_0-rmse:65.31253	validation_1-rmse:32.32235
# [85]	validation_0-rmse:65.20972	validation_1-rmse:32.24912
# [86]	validation_0-rmse:65.10870	validation_1-rmse:32.21412
# [87]	validation_0-rmse:65.00982	validation_1-rmse:32.17960
# [88]	validation_0-rmse:64.91234	validation_1-rmse:32.13913
# [89]	validation_0-rmse:64.81578	validation_1-rmse:32.10577
# [90]	validation_0-rmse:64.72098	validation_1-rmse:32.07287
# [91]	validation_0-rmse:64.62869	validation_1-rmse:32.03388
# [92]	validation_0-rmse:64.53752	validation_1-rmse:32.00206
# [93]	validation_0-rmse:64.44774	validation_1-rmse:31.97067
# [94]	validation_0-rmse:64.35986	validation_1-rmse:31.93971
# [95]	validation_0-rmse:64.27329	validation_1-rmse:31.90917
# [96]	validation_0-rmse:64.18862	validation_1-rmse:31.87905
# [97]	validation_0-rmse:64.10517	validation_1-rmse:31.84936
# [98]	validation_0-rmse:64.02328	validation_1-rmse:31.82008
# [99]	validation_0-rmse:63.94313	validation_1-rmse:31.79120
# [100]	validation_0-rmse:63.86418	validation_1-rmse:31.76270
# [101]	validation_0-rmse:63.78697	validation_1-rmse:31.73460
# [102]	validation_0-rmse:63.71109	validation_1-rmse:31.69556
# [103]	validation_0-rmse:63.63660	validation_1-rmse:31.63886
# [104]	validation_0-rmse:63.56350	validation_1-rmse:31.60112
# [105]	validation_0-rmse:63.49149	validation_1-rmse:31.57495
# [106]	validation_0-rmse:63.42106	validation_1-rmse:31.53823
# [107]	validation_0-rmse:63.35195	validation_1-rmse:31.50201
# [108]	validation_0-rmse:63.28408	validation_1-rmse:31.44905
# [109]	validation_0-rmse:63.21718	validation_1-rmse:31.42437
# [110]	validation_0-rmse:63.15184	validation_1-rmse:31.38979
# [111]	validation_0-rmse:63.08771	validation_1-rmse:31.35568
# [112]	validation_0-rmse:63.02473	validation_1-rmse:31.30552
# [113]	validation_0-rmse:62.96293	validation_1-rmse:31.25612
# [114]	validation_0-rmse:62.90233	validation_1-rmse:31.22301
# [115]	validation_0-rmse:62.84246	validation_1-rmse:31.20094
# [116]	validation_0-rmse:62.78409	validation_1-rmse:31.16863
# [117]	validation_0-rmse:62.72722	validation_1-rmse:31.13750
# [118]	validation_0-rmse:62.67137	validation_1-rmse:31.10678
# [119]	validation_0-rmse:62.61622	validation_1-rmse:31.07587
# [120]	validation_0-rmse:62.56250	validation_1-rmse:31.04594
# [121]	validation_0-rmse:62.50940	validation_1-rmse:31.01574
# [122]	validation_0-rmse:62.45763	validation_1-rmse:30.98657
# [123]	validation_0-rmse:62.40650	validation_1-rmse:30.95708
# [124]	validation_0-rmse:62.35672	validation_1-rmse:30.92865
# [125]	validation_0-rmse:62.30749	validation_1-rmse:30.89984
# [126]	validation_0-rmse:62.25957	validation_1-rmse:30.87213
# [127]	validation_0-rmse:62.21218	validation_1-rmse:30.84398
# [128]	validation_0-rmse:62.16565	validation_1-rmse:30.80331
# [129]	validation_0-rmse:62.11991	validation_1-rmse:30.76471
# [130]	validation_0-rmse:62.07503	validation_1-rmse:30.74983
# [131]	validation_0-rmse:62.03055	validation_1-rmse:30.73295
# [132]	validation_0-rmse:61.98734	validation_1-rmse:30.70663
# [133]	validation_0-rmse:61.94533	validation_1-rmse:30.68157
# [134]	validation_0-rmse:61.90348	validation_1-rmse:30.65586
# [135]	validation_0-rmse:61.86242	validation_1-rmse:30.64201
# [136]	validation_0-rmse:61.82277	validation_1-rmse:30.61785
# [137]	validation_0-rmse:61.78324	validation_1-rmse:30.59298
# [138]	validation_0-rmse:61.74470	validation_1-rmse:30.55846
# [139]	validation_0-rmse:61.70677	validation_1-rmse:30.54500
# [140]	validation_0-rmse:61.66911	validation_1-rmse:30.53019
# [141]	validation_0-rmse:61.63270	validation_1-rmse:30.49564
# [142]	validation_0-rmse:61.59642	validation_1-rmse:30.48133
# [143]	validation_0-rmse:61.56107	validation_1-rmse:30.46908
# [144]	validation_0-rmse:61.52638	validation_1-rmse:30.45695
# [145]	validation_0-rmse:61.49236	validation_1-rmse:30.44494
# [146]	validation_0-rmse:61.45922	validation_1-rmse:30.41366
# [147]	validation_0-rmse:61.42646	validation_1-rmse:30.40206
# [148]	validation_0-rmse:61.39455	validation_1-rmse:30.37157
# [149]	validation_0-rmse:61.36325	validation_1-rmse:30.34028
# [150]	validation_0-rmse:61.33243	validation_1-rmse:30.32943
# [151]	validation_0-rmse:61.30172	validation_1-rmse:30.31695
# [152]	validation_0-rmse:61.27160	validation_1-rmse:30.30459
# [153]	validation_0-rmse:61.24274	validation_1-rmse:30.29399
# [154]	validation_0-rmse:61.21443	validation_1-rmse:30.28349
# [155]	validation_0-rmse:61.18624	validation_1-rmse:30.27308
# [156]	validation_0-rmse:61.15882	validation_1-rmse:30.24542
# [157]	validation_0-rmse:61.13192	validation_1-rmse:30.21698
# [158]	validation_0-rmse:61.10569	validation_1-rmse:30.20718
# [159]	validation_0-rmse:61.07923	validation_1-rmse:30.19613
# [160]	validation_0-rmse:61.05356	validation_1-rmse:30.18652
# [161]	validation_0-rmse:61.02879	validation_1-rmse:30.17700
# [162]	validation_0-rmse:61.00450	validation_1-rmse:30.16757
# [163]	validation_0-rmse:60.98040	validation_1-rmse:30.14445
# [164]	validation_0-rmse:60.95628	validation_1-rmse:30.13418
# [165]	validation_0-rmse:60.93292	validation_1-rmse:30.12514
# [166]	validation_0-rmse:60.91002	validation_1-rmse:30.11652
# [167]	validation_0-rmse:60.88768	validation_1-rmse:30.09449
# [168]	validation_0-rmse:60.86562	validation_1-rmse:30.08691
# [169]	validation_0-rmse:60.84435	validation_1-rmse:30.07808
# [170]	validation_0-rmse:60.82312	validation_1-rmse:30.06994
# [171]	validation_0-rmse:60.80241	validation_1-rmse:30.04895
# [172]	validation_0-rmse:60.78209	validation_1-rmse:30.02824
# [173]	validation_0-rmse:60.76204	validation_1-rmse:30.02046
# [174]	validation_0-rmse:60.74195	validation_1-rmse:30.01486
# [175]	validation_0-rmse:60.72262	validation_1-rmse:30.00807
# [176]	validation_0-rmse:60.70399	validation_1-rmse:29.99994
# [177]	validation_0-rmse:60.68531	validation_1-rmse:29.99188
# [178]	validation_0-rmse:60.66706	validation_1-rmse:29.98454
# [179]	validation_0-rmse:60.64928	validation_1-rmse:29.97088
# [180]	validation_0-rmse:60.63185	validation_1-rmse:29.95738
# [181]	validation_0-rmse:60.61458	validation_1-rmse:29.95122
# [182]	validation_0-rmse:60.59796	validation_1-rmse:29.94359
# [183]	validation_0-rmse:60.58149	validation_1-rmse:29.93058
# [184]	validation_0-rmse:60.56519	validation_1-rmse:29.92381
# [185]	validation_0-rmse:60.54929	validation_1-rmse:29.91111
# [186]	validation_0-rmse:60.53360	validation_1-rmse:29.90451
# [187]	validation_0-rmse:60.51822	validation_1-rmse:29.89211
# [188]	validation_0-rmse:60.50312	validation_1-rmse:29.88589
# [189]	validation_0-rmse:60.48826	validation_1-rmse:29.87378
# [190]	validation_0-rmse:60.47373	validation_1-rmse:29.86774
# [191]	validation_0-rmse:60.45964	validation_1-rmse:29.85590
# [192]	validation_0-rmse:60.44577	validation_1-rmse:29.84421
# [193]	validation_0-rmse:60.43210	validation_1-rmse:29.83266
# [194]	validation_0-rmse:60.41862	validation_1-rmse:29.82698
# [195]	validation_0-rmse:60.40558	validation_1-rmse:29.81569
# [196]	validation_0-rmse:60.39267	validation_1-rmse:29.80453
# [197]	validation_0-rmse:60.38017	validation_1-rmse:29.79352
# [198]	validation_0-rmse:60.36767	validation_1-rmse:29.79066
# [199]	validation_0-rmse:60.35443	validation_1-rmse:29.77989
# [200]	validation_0-rmse:60.34144	validation_1-rmse:29.76926
# [201]	validation_0-rmse:60.32984	validation_1-rmse:29.75875
# [202]	validation_0-rmse:60.31824	validation_1-rmse:29.75623
# [203]	validation_0-rmse:60.30696	validation_1-rmse:29.74215
# [204]	validation_0-rmse:60.29492	validation_1-rmse:29.73152
# [205]	validation_0-rmse:60.28388	validation_1-rmse:29.71693
# [206]	validation_0-rmse:60.27275	validation_1-rmse:29.71483
# [207]	validation_0-rmse:60.26183	validation_1-rmse:29.71277
# [208]	validation_0-rmse:60.25147	validation_1-rmse:29.71074
# [209]	validation_0-rmse:60.24130	validation_1-rmse:29.70435
# [210]	validation_0-rmse:60.23134	validation_1-rmse:29.69802
# [211]	validation_0-rmse:60.22166	validation_1-rmse:29.68437
# [212]	validation_0-rmse:60.21206	validation_1-rmse:29.67821
# [213]	validation_0-rmse:60.20264	validation_1-rmse:29.67398
# [214]	validation_0-rmse:60.19264	validation_1-rmse:29.66865
# [215]	validation_0-rmse:60.18319	validation_1-rmse:29.66688
# [216]	validation_0-rmse:60.17356	validation_1-rmse:29.66160
# [217]	validation_0-rmse:60.16446	validation_1-rmse:29.65989
# [218]	validation_0-rmse:60.15553	validation_1-rmse:29.65822
# [219]	validation_0-rmse:60.14710	validation_1-rmse:29.65489
# [220]	validation_0-rmse:60.13813	validation_1-rmse:29.64971
# [221]	validation_0-rmse:60.12967	validation_1-rmse:29.64811
# [222]	validation_0-rmse:60.12138	validation_1-rmse:29.64653
# [223]	validation_0-rmse:60.11356	validation_1-rmse:29.64329
# [224]	validation_0-rmse:60.10528	validation_1-rmse:29.63494
# [225]	validation_0-rmse:60.09779	validation_1-rmse:29.63184
# [226]	validation_0-rmse:60.09008	validation_1-rmse:29.63042
# [227]	validation_0-rmse:60.08251	validation_1-rmse:29.62902
# [228]	validation_0-rmse:60.07509	validation_1-rmse:29.62744
# [229]	validation_0-rmse:60.06804	validation_1-rmse:29.61689
# [230]	validation_0-rmse:60.06112	validation_1-rmse:29.60646
# [231]	validation_0-rmse:60.05433	validation_1-rmse:29.59616
# [232]	validation_0-rmse:60.04742	validation_1-rmse:29.59508
# [233]	validation_0-rmse:60.04082	validation_1-rmse:29.59144
# [234]	validation_0-rmse:60.03448	validation_1-rmse:29.58818
# [235]	validation_0-rmse:60.02792	validation_1-rmse:29.58720
# [236]	validation_0-rmse:60.02166	validation_1-rmse:29.59280
# [237]	validation_0-rmse:60.01534	validation_1-rmse:29.59179
# [238]	validation_0-rmse:60.00930	validation_1-rmse:29.59732
# [239]	validation_0-rmse:60.00350	validation_1-rmse:29.60282
# [240]	validation_0-rmse:59.99749	validation_1-rmse:29.60177
# [241]	validation_0-rmse:59.99179	validation_1-rmse:29.59811
# [242]	validation_0-rmse:59.98631	validation_1-rmse:29.59525
# [243]	validation_0-rmse:59.98062	validation_1-rmse:29.59428
# [244]	validation_0-rmse:59.97503	validation_1-rmse:29.59333
# [245]	validation_0-rmse:59.96972	validation_1-rmse:29.59877
# [246]	validation_0-rmse:59.96454	validation_1-rmse:29.60418
# [247]	validation_0-rmse:59.95924	validation_1-rmse:29.60317
# [248]	validation_0-rmse:59.95404	validation_1-rmse:29.60196
# [249]	validation_0-rmse:59.94912	validation_1-rmse:29.60726
# [250]	validation_0-rmse:59.94411	validation_1-rmse:29.60625
# [251]	validation_0-rmse:59.93938	validation_1-rmse:29.61148
# [252]	validation_0-rmse:59.93469	validation_1-rmse:29.61045
# [253]	validation_0-rmse:59.92875	validation_1-rmse:29.60479
# [254]	validation_0-rmse:59.92423	validation_1-rmse:29.60359
# [255]	validation_0-rmse:59.91848	validation_1-rmse:29.59805
# [256]	validation_0-rmse:59.91283	validation_1-rmse:29.59258
# [257]	validation_0-rmse:59.90856	validation_1-rmse:29.59173
# [258]	validation_0-rmse:59.90309	validation_1-rmse:29.58636
# [259]	validation_0-rmse:59.89897	validation_1-rmse:29.58557
# [260]	validation_0-rmse:59.89368	validation_1-rmse:29.58031
# [261]	validation_0-rmse:59.88850	validation_1-rmse:29.57511
# [262]	validation_0-rmse:59.88451	validation_1-rmse:29.57442
# [263]	validation_0-rmse:59.88060	validation_1-rmse:29.57374
# [264]	validation_0-rmse:59.87686	validation_1-rmse:29.57635
# [265]	validation_0-rmse:59.87196	validation_1-rmse:29.57133
# [266]	validation_0-rmse:59.86836	validation_1-rmse:29.57393
# [267]	validation_0-rmse:59.86483	validation_1-rmse:29.57652
# [268]	validation_0-rmse:59.86138	validation_1-rmse:29.57161
# [269]	validation_0-rmse:59.85676	validation_1-rmse:29.56675
# [270]	validation_0-rmse:59.85223	validation_1-rmse:29.56195
# [271]	validation_0-rmse:59.84894	validation_1-rmse:29.56467
# [272]	validation_0-rmse:59.84571	validation_1-rmse:29.56734
# [273]	validation_0-rmse:59.84254	validation_1-rmse:29.57001
# [274]	validation_0-rmse:59.83885	validation_1-rmse:29.56535
# [275]	validation_0-rmse:59.83463	validation_1-rmse:29.56074
# [276]	validation_0-rmse:59.83050	validation_1-rmse:29.55622
# [277]	validation_0-rmse:59.82745	validation_1-rmse:29.55079
# [278]	validation_0-rmse:59.82333	validation_1-rmse:29.54537
# [279]	validation_0-rmse:59.81999	validation_1-rmse:29.54411
# [280]	validation_0-rmse:59.81610	validation_1-rmse:29.53975
# [281]	validation_0-rmse:59.81217	validation_1-rmse:29.53455
# [282]	validation_0-rmse:59.80838	validation_1-rmse:29.52804
# [283]	validation_0-rmse:59.80463	validation_1-rmse:29.52492
# [284]	validation_0-rmse:59.80097	validation_1-rmse:29.51854
# [285]	validation_0-rmse:59.79735	validation_1-rmse:29.51551
# [286]	validation_0-rmse:59.79382	validation_1-rmse:29.50927
# [287]	validation_0-rmse:59.79034	validation_1-rmse:29.50631
# [288]	validation_0-rmse:59.78693	validation_1-rmse:29.50020
# [289]	validation_0-rmse:59.78354	validation_1-rmse:29.49546
# [290]	validation_0-rmse:59.78024	validation_1-rmse:29.48947
# [291]	validation_0-rmse:59.77702	validation_1-rmse:29.48355
# [292]	validation_0-rmse:59.77382	validation_1-rmse:29.48081
# [293]	validation_0-rmse:59.77071	validation_1-rmse:29.47501
# [294]	validation_0-rmse:59.76762	validation_1-rmse:29.47232
# [295]	validation_0-rmse:59.76461	validation_1-rmse:29.46665
# [296]	validation_0-rmse:59.76163	validation_1-rmse:29.46364
# [297]	validation_0-rmse:59.75872	validation_1-rmse:29.45832
# [298]	validation_0-rmse:59.75581	validation_1-rmse:29.45403
# [299]	validation_0-rmse:59.75300	validation_1-rmse:29.44882
# [300]	validation_0-rmse:59.75017	validation_1-rmse:29.44529
# [301]	validation_0-rmse:59.74746	validation_1-rmse:29.44020
# [302]	validation_0-rmse:59.74473	validation_1-rmse:29.43678
# [303]	validation_0-rmse:59.74159	validation_1-rmse:29.43181
# [304]	validation_0-rmse:59.73926	validation_1-rmse:29.42826
# [305]	validation_0-rmse:59.73622	validation_1-rmse:29.42341
# [306]	validation_0-rmse:59.73366	validation_1-rmse:29.42012
# [307]	validation_0-rmse:59.73072	validation_1-rmse:29.41539
# [308]	validation_0-rmse:59.72854	validation_1-rmse:29.41210
# [309]	validation_0-rmse:59.72568	validation_1-rmse:29.40748
# [310]	validation_0-rmse:59.72287	validation_1-rmse:29.40292
# [311]	validation_0-rmse:59.72085	validation_1-rmse:29.39981
# [312]	validation_0-rmse:59.71852	validation_1-rmse:29.39674
# [313]	validation_0-rmse:59.71593	validation_1-rmse:29.40368
# [314]	validation_0-rmse:59.71340	validation_1-rmse:29.41057
# [315]	validation_0-rmse:59.71146	validation_1-rmse:29.41740
# [316]	validation_0-rmse:59.70946	validation_1-rmse:29.41444
# [317]	validation_0-rmse:59.70764	validation_1-rmse:29.41151
# [318]	validation_0-rmse:59.70524	validation_1-rmse:29.41834
# [319]	validation_0-rmse:59.70289	validation_1-rmse:29.42512
# [320]	validation_0-rmse:59.70102	validation_1-rmse:29.42228
# [321]	validation_0-rmse:59.69874	validation_1-rmse:29.42902
# [322]	validation_0-rmse:59.69697	validation_1-rmse:29.42156
# [323]	validation_0-rmse:59.69534	validation_1-rmse:29.41808
# [324]	validation_0-rmse:59.69375	validation_1-rmse:29.41464
# [325]	validation_0-rmse:59.69219	validation_1-rmse:29.41126
# [326]	validation_0-rmse:59.69071	validation_1-rmse:29.40583
# [327]	validation_0-rmse:59.68926	validation_1-rmse:29.40035
# [328]	validation_0-rmse:59.68736	validation_1-rmse:29.40723
# [329]	validation_0-rmse:59.68564	validation_1-rmse:29.40043
# [330]	validation_0-rmse:59.68421	validation_1-rmse:29.39732
# [331]	validation_0-rmse:59.68255	validation_1-rmse:29.39063
# [332]	validation_0-rmse:59.68117	validation_1-rmse:29.38756
# [333]	validation_0-rmse:59.67981	validation_1-rmse:29.38463
# [334]	validation_0-rmse:59.67822	validation_1-rmse:29.37809
# [335]	validation_0-rmse:59.67691	validation_1-rmse:29.37732
# [336]	validation_0-rmse:59.67567	validation_1-rmse:29.37243
# [337]	validation_0-rmse:59.67446	validation_1-rmse:29.36750
# [338]	validation_0-rmse:59.67273	validation_1-rmse:29.36197
# [339]	validation_0-rmse:59.67103	validation_1-rmse:29.35650
# [340]	validation_0-rmse:59.66937	validation_1-rmse:29.35109
# [341]	validation_0-rmse:59.66775	validation_1-rmse:29.34583
# [342]	validation_0-rmse:59.66624	validation_1-rmse:29.34053
# [343]	validation_0-rmse:59.66495	validation_1-rmse:29.33410
# [344]	validation_0-rmse:59.66369	validation_1-rmse:29.32774
# [345]	validation_0-rmse:59.66245	validation_1-rmse:29.32145
# [346]	validation_0-rmse:59.66134	validation_1-rmse:29.32121
# [347]	validation_0-rmse:59.65984	validation_1-rmse:29.31626
# [348]	validation_0-rmse:59.65885	validation_1-rmse:29.31539
# [349]	validation_0-rmse:59.65779	validation_1-rmse:29.31321
# [350]	validation_0-rmse:59.65675	validation_1-rmse:29.31307
# [351]	validation_0-rmse:59.65532	validation_1-rmse:29.30818
# [352]	validation_0-rmse:59.65439	validation_1-rmse:29.30738
# [353]	validation_0-rmse:59.65340	validation_1-rmse:29.30532
# [354]	validation_0-rmse:59.65250	validation_1-rmse:29.30454
# [355]	validation_0-rmse:59.65154	validation_1-rmse:29.30255
# [356]	validation_0-rmse:59.65054	validation_1-rmse:29.30058
# [357]	validation_0-rmse:59.64956	validation_1-rmse:29.29850
# [358]	validation_0-rmse:59.64826	validation_1-rmse:29.29387
# [359]	validation_0-rmse:59.64734	validation_1-rmse:29.29325
# [360]	validation_0-rmse:59.64645	validation_1-rmse:29.29264
# [361]	validation_0-rmse:59.64557	validation_1-rmse:29.29195
# [362]	validation_0-rmse:59.64408	validation_1-rmse:29.29047
# [363]	validation_0-rmse:59.64258	validation_1-rmse:29.28857
# [364]	validation_0-rmse:59.64113	validation_1-rmse:29.28716
# [365]	validation_0-rmse:59.64029	validation_1-rmse:29.28660
# [366]	validation_0-rmse:59.63885	validation_1-rmse:29.28478
# [367]	validation_0-rmse:59.63746	validation_1-rmse:29.28346
# [368]	validation_0-rmse:59.63631	validation_1-rmse:29.27996
# [369]	validation_0-rmse:59.63554	validation_1-rmse:29.27945
# [370]	validation_0-rmse:59.63420	validation_1-rmse:29.27819
# [371]	validation_0-rmse:59.63344	validation_1-rmse:29.27770
# [372]	validation_0-rmse:59.63210	validation_1-rmse:29.27603
# [373]	validation_0-rmse:59.63079	validation_1-rmse:29.27496
# [374]	validation_0-rmse:59.63008	validation_1-rmse:29.27449
# [375]	validation_0-rmse:59.62881	validation_1-rmse:29.27346
# [376]	validation_0-rmse:59.62752	validation_1-rmse:29.27189
# [377]	validation_0-rmse:59.62628	validation_1-rmse:29.27092
# [378]	validation_0-rmse:59.62528	validation_1-rmse:29.26772
# [379]	validation_0-rmse:59.62462	validation_1-rmse:29.26737
# [380]	validation_0-rmse:59.62343	validation_1-rmse:29.26636
# [381]	validation_0-rmse:59.62266	validation_1-rmse:29.26602
# [382]	validation_0-rmse:59.62150	validation_1-rmse:29.26506
# [383]	validation_0-rmse:59.62076	validation_1-rmse:29.26473
# [384]	validation_0-rmse:59.61964	validation_1-rmse:29.26399
# [385]	validation_0-rmse:59.61892	validation_1-rmse:29.26369
# [386]	validation_0-rmse:59.61782	validation_1-rmse:29.26281
# [387]	validation_0-rmse:59.61713	validation_1-rmse:29.26244
# [388]	validation_0-rmse:59.61607	validation_1-rmse:29.26179
# [389]	validation_0-rmse:59.61539	validation_1-rmse:29.26143
# [390]	validation_0-rmse:59.61435	validation_1-rmse:29.26064
# [391]	validation_0-rmse:59.61377	validation_1-rmse:29.26233
# [392]	validation_0-rmse:59.61270	validation_1-rmse:29.26130
# [393]	validation_0-rmse:59.61216	validation_1-rmse:29.26132
# [394]	validation_0-rmse:59.61115	validation_1-rmse:29.26077
# [395]	validation_0-rmse:59.61054	validation_1-rmse:29.25999
# [396]	validation_0-rmse:59.60956	validation_1-rmse:29.25922
# [397]	validation_0-rmse:59.60856	validation_1-rmse:29.25911
# [398]	validation_0-rmse:59.60756	validation_1-rmse:29.25822
# [399]	validation_0-rmse:59.60707	validation_1-rmse:29.25833
# [400]	validation_0-rmse:59.60613	validation_1-rmse:29.25774
# [401]	validation_0-rmse:59.60521	validation_1-rmse:29.25717
# [402]	validation_0-rmse:59.60474	validation_1-rmse:29.25225
# [403]	validation_0-rmse:59.60379	validation_1-rmse:29.25223
# [404]	validation_0-rmse:59.60334	validation_1-rmse:29.24739
# [405]	validation_0-rmse:59.60246	validation_1-rmse:29.24690
# [406]	validation_0-rmse:59.60202	validation_1-rmse:29.24238
# [407]	validation_0-rmse:59.60115	validation_1-rmse:29.24193
# [408]	validation_0-rmse:59.60073	validation_1-rmse:29.23748
# [409]	validation_0-rmse:59.59985	validation_1-rmse:29.23736
# [410]	validation_0-rmse:59.59862	validation_1-rmse:29.23847
# [411]	validation_0-rmse:59.59741	validation_1-rmse:29.23958
# [412]	validation_0-rmse:59.59700	validation_1-rmse:29.23990
# [413]	validation_0-rmse:59.59620	validation_1-rmse:29.23952
# [414]	validation_0-rmse:59.59502	validation_1-rmse:29.24069
# [415]	validation_0-rmse:59.59464	validation_1-rmse:29.24104
# [416]	validation_0-rmse:59.59383	validation_1-rmse:29.24120
# [417]	validation_0-rmse:59.59270	validation_1-rmse:29.24239
# [418]	validation_0-rmse:59.59158	validation_1-rmse:29.24357
# [419]	validation_0-rmse:59.59077	validation_1-rmse:29.24295
# [420]	validation_0-rmse:59.58998	validation_1-rmse:29.24234
# [421]	validation_0-rmse:59.58926	validation_1-rmse:29.24158
# [422]	validation_0-rmse:59.58891	validation_1-rmse:29.24197
# [423]	validation_0-rmse:59.58821	validation_1-rmse:29.24125
# [424]	validation_0-rmse:59.58717	validation_1-rmse:29.24245
# [425]	validation_0-rmse:59.58641	validation_1-rmse:29.24818
# [426]	validation_0-rmse:59.58539	validation_1-rmse:29.24934
# [427]	validation_0-rmse:59.58466	validation_1-rmse:29.25496
# [428]	validation_0-rmse:59.58394	validation_1-rmse:29.25443
# [429]	validation_0-rmse:59.58324	validation_1-rmse:29.25460
# [430]	validation_0-rmse:59.58254	validation_1-rmse:29.26013
# [431]	validation_0-rmse:59.58183	validation_1-rmse:29.26067
# [432]	validation_0-rmse:59.58143	validation_1-rmse:29.26178
# [433]	validation_0-rmse:59.58076	validation_1-rmse:29.26130
# [434]	validation_0-rmse:59.58010	validation_1-rmse:29.26083
# [435]	validation_0-rmse:59.57944	validation_1-rmse:29.26622
# [436]	validation_0-rmse:59.57915	validation_1-rmse:29.26726
# [437]	validation_0-rmse:59.57847	validation_1-rmse:29.26778
# [438]	validation_0-rmse:59.57784	validation_1-rmse:29.26734
# [439]	validation_0-rmse:59.57756	validation_1-rmse:29.26838
# [440]	validation_0-rmse:59.57695	validation_1-rmse:29.26796
# [441]	validation_0-rmse:59.57661	validation_1-rmse:29.26900
# [442]	validation_0-rmse:59.57601	validation_1-rmse:29.26859
# [443]	validation_0-rmse:59.57543	validation_1-rmse:29.27373
# [444]	validation_0-rmse:59.57514	validation_1-rmse:29.27474
# [445]	validation_0-rmse:59.57456	validation_1-rmse:29.27401
# [446]	validation_0-rmse:59.57427	validation_1-rmse:29.27503
# [447]	validation_0-rmse:59.57371	validation_1-rmse:29.27431
# [448]	validation_0-rmse:59.57341	validation_1-rmse:29.27534
# [449]	validation_0-rmse:59.57286	validation_1-rmse:29.27496
# [450]	validation_0-rmse:59.57258	validation_1-rmse:29.27599
# [451]	validation_0-rmse:59.57205	validation_1-rmse:29.27530
# [452]	validation_0-rmse:59.57153	validation_1-rmse:29.27490
# [453]	validation_0-rmse:59.57126	validation_1-rmse:29.27594
# [454]	validation_0-rmse:59.57101	validation_1-rmse:29.27697
# [455]	validation_0-rmse:59.57049	validation_1-rmse:29.27630
# [456]	validation_0-rmse:59.56999	validation_1-rmse:29.27595
# [457]	validation_0-rmse:59.56950	validation_1-rmse:29.27413
# [458]	validation_0-rmse:59.56927	validation_1-rmse:29.27525
# [459]	validation_0-rmse:59.56878	validation_1-rmse:29.27460
# [460]	validation_0-rmse:59.56829	validation_1-rmse:29.27423
# [461]	validation_0-rmse:59.56785	validation_1-rmse:29.27246
# [462]	validation_0-rmse:59.56762	validation_1-rmse:29.26965
# [463]	validation_0-rmse:59.56740	validation_1-rmse:29.27083
# [464]	validation_0-rmse:59.56693	validation_1-rmse:29.27050
# [465]	validation_0-rmse:59.56647	validation_1-rmse:29.27514
# [466]	validation_0-rmse:59.56603	validation_1-rmse:29.27238
# [467]	validation_0-rmse:59.56558	validation_1-rmse:29.27203
# [468]	validation_0-rmse:59.56516	validation_1-rmse:29.27216
# [469]	validation_0-rmse:59.56496	validation_1-rmse:29.27050
# [470]	validation_0-rmse:59.56452	validation_1-rmse:29.27503
# [471]	validation_0-rmse:59.56412	validation_1-rmse:29.27235
# [472]	validation_0-rmse:59.56370	validation_1-rmse:29.27202
# [473]	validation_0-rmse:59.56330	validation_1-rmse:29.27218
# [474]	validation_0-rmse:59.56289	validation_1-rmse:29.27158
# [475]	validation_0-rmse:59.56247	validation_1-rmse:29.27629
# [476]	validation_0-rmse:59.56229	validation_1-rmse:29.27561
# [477]	validation_0-rmse:59.56210	validation_1-rmse:29.27495
# [478]	validation_0-rmse:59.56170	validation_1-rmse:29.27934
# [479]	validation_0-rmse:59.56129	validation_1-rmse:29.27673
# [480]	validation_0-rmse:59.56092	validation_1-rmse:29.27515
# [481]	validation_0-rmse:59.56052	validation_1-rmse:29.27976
# [482]	validation_0-rmse:59.56034	validation_1-rmse:29.27913
# [483]	validation_0-rmse:59.56016	validation_1-rmse:29.27850
# [484]	validation_0-rmse:59.55977	validation_1-rmse:29.28280
# [485]	validation_0-rmse:59.55937	validation_1-rmse:29.28089
# [486]	validation_0-rmse:59.55920	validation_1-rmse:29.28028
# [487]	validation_0-rmse:59.55899	validation_1-rmse:29.27839
# [488]	validation_0-rmse:59.55861	validation_1-rmse:29.28290
# [489]	validation_0-rmse:59.55822	validation_1-rmse:29.28103
# [490]	validation_0-rmse:59.55806	validation_1-rmse:29.28044
# [491]	validation_0-rmse:59.55790	validation_1-rmse:29.27986
# [492]	validation_0-rmse:59.55754	validation_1-rmse:29.28407
# [493]	validation_0-rmse:59.55716	validation_1-rmse:29.28222
# [494]	validation_0-rmse:59.55700	validation_1-rmse:29.28166
# [495]	validation_0-rmse:59.55665	validation_1-rmse:29.28605
# [496]	validation_0-rmse:59.55628	validation_1-rmse:29.28287
# [497]	validation_0-rmse:59.55609	validation_1-rmse:29.28106
# [498]	validation_0-rmse:59.55594	validation_1-rmse:29.28052
# [499]	validation_0-rmse:59.55558	validation_1-rmse:29.27741
# [500]	validation_0-rmse:59.55543	validation_1-rmse:29.27704
# [501]	validation_0-rmse:59.55529	validation_1-rmse:29.27652
# [502]	validation_0-rmse:59.55511	validation_1-rmse:29.27478
# [503]	validation_0-rmse:59.55478	validation_1-rmse:29.27890
# [504]	validation_0-rmse:59.55464	validation_1-rmse:29.27839
# [505]	validation_0-rmse:59.55429	validation_1-rmse:29.27535
# [506]	validation_0-rmse:59.55416	validation_1-rmse:29.27501
# [507]	validation_0-rmse:59.55398	validation_1-rmse:29.27201
# [508]	validation_0-rmse:59.55385	validation_1-rmse:29.27153
# [509]	validation_0-rmse:59.55361	validation_1-rmse:29.27192
# [510]	validation_0-rmse:59.55338	validation_1-rmse:29.27230
# [511]	validation_0-rmse:59.55315	validation_1-rmse:29.27269
# [512]	validation_0-rmse:59.55290	validation_1-rmse:29.27260
# [513]	validation_0-rmse:59.55264	validation_1-rmse:29.27251
# [514]	validation_0-rmse:59.55248	validation_1-rmse:29.26969
# [515]	validation_0-rmse:59.55223	validation_1-rmse:29.26961
# [516]	validation_0-rmse:59.55199	validation_1-rmse:29.26954
# [517]	validation_0-rmse:59.55179	validation_1-rmse:29.26823
# [518]	validation_0-rmse:59.55159	validation_1-rmse:29.27098
# [519]	validation_0-rmse:59.55140	validation_1-rmse:29.26969
# [520]	validation_0-rmse:59.55120	validation_1-rmse:29.27009
# [521]	validation_0-rmse:59.55101	validation_1-rmse:29.26882
# [522]	validation_0-rmse:59.55083	validation_1-rmse:29.26758
# [523]	validation_0-rmse:59.55061	validation_1-rmse:29.26752
# [524]	validation_0-rmse:59.55051	validation_1-rmse:29.27281
# [525]	validation_0-rmse:59.55040	validation_1-rmse:29.27384
# [526]	validation_0-rmse:59.55028	validation_1-rmse:29.27478
# [527]	validation_0-rmse:59.55017	validation_1-rmse:29.27571
# [528]	validation_0-rmse:59.55006	validation_1-rmse:29.28184
# [529]	validation_0-rmse:59.54995	validation_1-rmse:29.28286
# [530]	validation_0-rmse:59.54985	validation_1-rmse:29.28378
# [531]	validation_0-rmse:59.54975	validation_1-rmse:29.29000
# [532]	validation_0-rmse:59.54964	validation_1-rmse:29.29082
# [533]	validation_0-rmse:59.54954	validation_1-rmse:29.29158
# [534]	validation_0-rmse:59.54943	validation_1-rmse:29.29275
# [535]	validation_0-rmse:59.54933	validation_1-rmse:29.29332
# [536]	validation_0-rmse:59.54924	validation_1-rmse:29.29936
# [537]	validation_0-rmse:59.54914	validation_1-rmse:29.30027
# [538]	validation_0-rmse:59.54904	validation_1-rmse:29.30083
# [539]	validation_0-rmse:59.54875	validation_1-rmse:29.30068
# [540]	validation_0-rmse:59.54855	validation_1-rmse:29.30026
# [541]	validation_0-rmse:59.54847	validation_1-rmse:29.30116
# [542]	validation_0-rmse:59.54840	validation_1-rmse:29.30571
# [543]	validation_0-rmse:59.54832	validation_1-rmse:29.30661
# [544]	validation_0-rmse:59.54823	validation_1-rmse:29.30796
# [545]	validation_0-rmse:59.54814	validation_1-rmse:29.30852
# [546]	validation_0-rmse:59.54805	validation_1-rmse:29.30943
# [547]	validation_0-rmse:59.54797	validation_1-rmse:29.31057
# [548]	validation_0-rmse:59.54789	validation_1-rmse:29.31133
# [549]	validation_0-rmse:59.54781	validation_1-rmse:29.31224
# [550]	validation_0-rmse:59.54753	validation_1-rmse:29.31209
# [551]	validation_0-rmse:59.54745	validation_1-rmse:29.31217
# [552]	validation_0-rmse:59.54739	validation_1-rmse:29.31308
# [553]	validation_0-rmse:59.54730	validation_1-rmse:29.31384
# [554]	validation_0-rmse:59.54722	validation_1-rmse:29.31499
# [555]	validation_0-rmse:59.54715	validation_1-rmse:29.31576
# [556]	validation_0-rmse:59.54707	validation_1-rmse:29.31707
# [557]	validation_0-rmse:59.54699	validation_1-rmse:29.31801
# [558]	validation_0-rmse:59.54692	validation_1-rmse:29.31860
# [559]	validation_0-rmse:59.54665	validation_1-rmse:29.31846
# [560]	validation_0-rmse:59.54637	validation_1-rmse:29.31831
# [561]	validation_0-rmse:59.54631	validation_1-rmse:29.31908
# [562]	validation_0-rmse:59.54613	validation_1-rmse:29.32017
# [563]	validation_0-rmse:59.54606	validation_1-rmse:29.32131
# [564]	validation_0-rmse:59.54600	validation_1-rmse:29.32225
# [565]	validation_0-rmse:59.54584	validation_1-rmse:29.32144
# [566]	validation_0-rmse:59.54578	validation_1-rmse:29.32222
# [567]	validation_0-rmse:59.54561	validation_1-rmse:29.32330
# [568]	validation_0-rmse:59.54534	validation_1-rmse:29.32340
# [569]	validation_0-rmse:59.54526	validation_1-rmse:29.32374
# [570]	validation_0-rmse:59.54520	validation_1-rmse:29.32452
# [571]	validation_0-rmse:59.54504	validation_1-rmse:29.32469
# [572]	validation_0-rmse:59.54498	validation_1-rmse:29.32571
# [573]	validation_0-rmse:59.54490	validation_1-rmse:29.32696
# [574]	validation_0-rmse:59.54485	validation_1-rmse:29.32776
# [575]	validation_0-rmse:59.54469	validation_1-rmse:29.32793
# [576]	validation_0-rmse:59.54442	validation_1-rmse:29.32806
# [577]	validation_0-rmse:59.54426	validation_1-rmse:29.32680
# [578]	validation_0-rmse:59.54421	validation_1-rmse:29.32760
# [579]	validation_0-rmse:59.54414	validation_1-rmse:29.32686
# [580]	validation_0-rmse:59.54407	validation_1-rmse:29.32703
# [581]	validation_0-rmse:59.54402	validation_1-rmse:29.32800
# [582]	validation_0-rmse:59.54387	validation_1-rmse:29.32820
# [583]	validation_0-rmse:59.54382	validation_1-rmse:29.32902
# [584]	validation_0-rmse:59.54367	validation_1-rmse:29.32923
# [585]	validation_0-rmse:59.54362	validation_1-rmse:29.33028
# [586]	validation_0-rmse:59.54347	validation_1-rmse:29.33049
# [587]	validation_0-rmse:59.54334	validation_1-rmse:29.33019
# [588]	validation_0-rmse:59.54321	validation_1-rmse:29.32840
# [589]	validation_0-rmse:59.54307	validation_1-rmse:29.32776
# [590]	validation_0-rmse:59.54294	validation_1-rmse:29.32747
# [591]	validation_0-rmse:59.54281	validation_1-rmse:29.32571
# [592]	validation_0-rmse:59.54269	validation_1-rmse:29.32396
# [593]	validation_0-rmse:59.54256	validation_1-rmse:29.32224
# [594]	validation_0-rmse:59.54244	validation_1-rmse:29.32054
# [595]	validation_0-rmse:59.54228	validation_1-rmse:29.31946
# [596]	validation_0-rmse:59.54197	validation_1-rmse:29.31919
# [597]	validation_0-rmse:59.54168	validation_1-rmse:29.31747
# [598]	validation_0-rmse:59.54138	validation_1-rmse:29.31581
# [599]	validation_0-rmse:59.54125	validation_1-rmse:29.31693
# [600]	validation_0-rmse:59.54113	validation_1-rmse:29.31525
# [601]	validation_0-rmse:59.54084	validation_1-rmse:29.31364
# [602]	validation_0-rmse:59.54069	validation_1-rmse:29.31311
# [603]	validation_0-rmse:59.54041	validation_1-rmse:29.31148
# [604]	validation_0-rmse:59.54014	validation_1-rmse:29.30986
# [605]	validation_0-rmse:59.54000	validation_1-rmse:29.31060
# [606]	validation_0-rmse:59.53973	validation_1-rmse:29.31186
# [607]	validation_0-rmse:59.53951	validation_1-rmse:29.31213
# [608]	validation_0-rmse:59.53943	validation_1-rmse:29.31217
# [609]	validation_0-rmse:59.53921	validation_1-rmse:29.31244
# [610]	validation_0-rmse:59.53914	validation_1-rmse:29.31231
# [611]	validation_0-rmse:59.53892	validation_1-rmse:29.31258
# [612]	validation_0-rmse:59.53885	validation_1-rmse:29.31263
# [613]	validation_0-rmse:59.53859	validation_1-rmse:29.31157
# [614]	validation_0-rmse:59.53838	validation_1-rmse:29.31184
# [615]	validation_0-rmse:59.53831	validation_1-rmse:29.31191
# [616]	validation_0-rmse:59.53824	validation_1-rmse:29.31574
# [617]	validation_0-rmse:59.53819	validation_1-rmse:29.31537
# [618]	validation_0-rmse:59.53813	validation_1-rmse:29.31676
# [619]	validation_0-rmse:59.53788	validation_1-rmse:29.31530
# [620]	validation_0-rmse:59.53783	validation_1-rmse:29.31882
# [621]	validation_0-rmse:59.53779	validation_1-rmse:29.31979
# [622]	validation_0-rmse:59.53774	validation_1-rmse:29.31929
# [623]	validation_0-rmse:59.53769	validation_1-rmse:29.32111
# [624]	validation_0-rmse:59.53745	validation_1-rmse:29.31967
# [625]	validation_0-rmse:59.53740	validation_1-rmse:29.32146
# [626]	validation_0-rmse:59.53736	validation_1-rmse:29.32024
# [627]	validation_0-rmse:59.53732	validation_1-rmse:29.32201
# [628]	validation_0-rmse:59.53708	validation_1-rmse:29.32059
# [629]	validation_0-rmse:59.53704	validation_1-rmse:29.31966
# [630]	validation_0-rmse:59.53699	validation_1-rmse:29.32140
# [631]	validation_0-rmse:59.53680	validation_1-rmse:29.32109
# [632]	validation_0-rmse:59.53661	validation_1-rmse:29.32079
# [633]	validation_0-rmse:59.53643	validation_1-rmse:29.32049
# [634]	validation_0-rmse:59.53636	validation_1-rmse:29.32098
# [635]	validation_0-rmse:59.53616	validation_1-rmse:29.32149
# [636]	validation_0-rmse:59.53598	validation_1-rmse:29.32119
# [637]	validation_0-rmse:59.53580	validation_1-rmse:29.32089
# [638]	validation_0-rmse:59.53574	validation_1-rmse:29.32016
# [639]	validation_0-rmse:59.53569	validation_1-rmse:29.31943
# [640]	validation_0-rmse:59.53562	validation_1-rmse:29.31994
# [641]	validation_0-rmse:59.53557	validation_1-rmse:29.31917
# [642]	validation_0-rmse:59.53537	validation_1-rmse:29.31968
# [643]	validation_0-rmse:59.53508	validation_1-rmse:29.31910
# [644]	validation_0-rmse:59.53502	validation_1-rmse:29.31850
# [645]	validation_0-rmse:59.53496	validation_1-rmse:29.31785
# [646]	validation_0-rmse:59.53491	validation_1-rmse:29.31717
# [647]	validation_0-rmse:59.53485	validation_1-rmse:29.31763
# [648]	validation_0-rmse:59.53480	validation_1-rmse:29.31697
# [649]	validation_0-rmse:59.53474	validation_1-rmse:29.31746
# [650]	validation_0-rmse:59.53455	validation_1-rmse:29.31796
# [651]	validation_0-rmse:59.53426	validation_1-rmse:29.31720
# [652]	validation_0-rmse:59.53420	validation_1-rmse:29.31666
# [653]	validation_0-rmse:59.53416	validation_1-rmse:29.31598
# [654]	validation_0-rmse:59.53411	validation_1-rmse:29.31531
# [655]	validation_0-rmse:59.53406	validation_1-rmse:29.31424
# [656]	validation_0-rmse:59.53398	validation_1-rmse:29.31547
# [657]	validation_0-rmse:59.53379	validation_1-rmse:29.31598
# [658]	validation_0-rmse:59.53351	validation_1-rmse:29.31526
# [659]	validation_0-rmse:59.53346	validation_1-rmse:29.31472
# [660]	validation_0-rmse:59.53341	validation_1-rmse:29.31837
# [661]	validation_0-rmse:59.53333	validation_1-rmse:29.31825
# [662]	validation_0-rmse:59.53325	validation_1-rmse:29.31947
# [663]	validation_0-rmse:59.53308	validation_1-rmse:29.32000
# [664]	validation_0-rmse:59.53281	validation_1-rmse:29.31933
# [665]	validation_0-rmse:59.53276	validation_1-rmse:29.31882
# [666]	validation_0-rmse:59.53268	validation_1-rmse:29.31873
# [667]	validation_0-rmse:59.53261	validation_1-rmse:29.31995
# [668]	validation_0-rmse:59.53242	validation_1-rmse:29.32127
# [669]	validation_0-rmse:59.53222	validation_1-rmse:29.32014
# [670]	validation_0-rmse:59.53204	validation_1-rmse:29.32146
# [671]	validation_0-rmse:59.53202	validation_1-rmse:29.32117
# [672]	validation_0-rmse:59.53195	validation_1-rmse:29.31995
# [673]	validation_0-rmse:59.53189	validation_1-rmse:29.31785
# [674]	validation_0-rmse:59.53171	validation_1-rmse:29.31916
# [675]	validation_0-rmse:59.53170	validation_1-rmse:29.31889
# [676]	validation_0-rmse:59.53168	validation_1-rmse:29.31862
# [677]	validation_0-rmse:59.53166	validation_1-rmse:29.31835
# [678]	validation_0-rmse:59.53161	validation_1-rmse:29.31621
# [679]	validation_0-rmse:59.53155	validation_1-rmse:29.31504
# [680]	validation_0-rmse:59.53137	validation_1-rmse:29.31633
# [681]	validation_0-rmse:59.53135	validation_1-rmse:29.31608
# [682]	validation_0-rmse:59.53134	validation_1-rmse:29.31582
# [683]	validation_0-rmse:59.53129	validation_1-rmse:29.31373
# [684]	validation_0-rmse:59.53123	validation_1-rmse:29.31251
# [685]	validation_0-rmse:59.53117	validation_1-rmse:29.31134
# [686]	validation_0-rmse:59.53100	validation_1-rmse:29.31266
# [687]	validation_0-rmse:59.53098	validation_1-rmse:29.31406
# [688]	validation_0-rmse:59.53096	validation_1-rmse:29.31546
# [689]	validation_0-rmse:59.53093	validation_1-rmse:29.31634
# [690]	validation_0-rmse:59.53091	validation_1-rmse:29.31620
# [691]	validation_0-rmse:59.53074	validation_1-rmse:29.31749
# [692]	validation_0-rmse:59.53072	validation_1-rmse:29.31725
# [693]	validation_0-rmse:59.53066	validation_1-rmse:29.31649
# [694]	validation_0-rmse:59.53061	validation_1-rmse:29.31460
# [695]	validation_0-rmse:59.53058	validation_1-rmse:29.31544
# [696]	validation_0-rmse:59.53051	validation_1-rmse:29.31466
# [697]	validation_0-rmse:59.53048	validation_1-rmse:29.31464
# [698]	validation_0-rmse:59.53046	validation_1-rmse:29.31450
# [699]	validation_0-rmse:59.53044	validation_1-rmse:29.31436
# [700]	validation_0-rmse:59.53035	validation_1-rmse:29.31319
# [701]	validation_0-rmse:59.53028	validation_1-rmse:29.31246
# [702]	validation_0-rmse:59.53022	validation_1-rmse:29.31173
# [703]	validation_0-rmse:59.53012	validation_1-rmse:29.31055
# [704]	validation_0-rmse:59.53006	validation_1-rmse:29.30985
# [705]	validation_0-rmse:59.53000	validation_1-rmse:29.30915
# [706]	validation_0-rmse:59.52997	validation_1-rmse:29.31000
# [707]	validation_0-rmse:59.52991	validation_1-rmse:29.30932
# [708]	validation_0-rmse:59.52986	validation_1-rmse:29.30864
# [709]	validation_0-rmse:59.52977	validation_1-rmse:29.30833
# [710]	validation_0-rmse:59.52974	validation_1-rmse:29.30917
# [711]	validation_0-rmse:59.52968	validation_1-rmse:29.30851
# [712]	validation_0-rmse:59.52963	validation_1-rmse:29.30786
# [713]	validation_0-rmse:59.52954	validation_1-rmse:29.30756
# [714]	validation_0-rmse:59.52930	validation_1-rmse:29.30957
# [715]	validation_0-rmse:59.52915	validation_1-rmse:29.31087
# [716]	validation_0-rmse:59.52909	validation_1-rmse:29.31025
# [717]	validation_0-rmse:59.52902	validation_1-rmse:29.31015
# [718]	validation_0-rmse:59.52897	validation_1-rmse:29.30954
# [719]	validation_0-rmse:59.52892	validation_1-rmse:29.30895
# [720]	validation_0-rmse:59.52877	validation_1-rmse:29.30756
# [721]	validation_0-rmse:59.52872	validation_1-rmse:29.30743
# [722]	validation_0-rmse:59.52857	validation_1-rmse:29.30611
# [723]	validation_0-rmse:59.52853	validation_1-rmse:29.30598
# [724]	validation_0-rmse:59.52844	validation_1-rmse:29.30545
# [725]	validation_0-rmse:59.52840	validation_1-rmse:29.30533
# [726]	validation_0-rmse:59.52820	validation_1-rmse:29.30576
# [727]	validation_0-rmse:59.52815	validation_1-rmse:29.30519
# [728]	validation_0-rmse:59.52801	validation_1-rmse:29.30390
# [729]	validation_0-rmse:59.52797	validation_1-rmse:29.30378
# [730]	validation_0-rmse:59.52788	validation_1-rmse:29.30326
# [731]	validation_0-rmse:59.52769	validation_1-rmse:29.30369
# [732]	validation_0-rmse:59.52762	validation_1-rmse:29.30377
# [733]	validation_0-rmse:59.52758	validation_1-rmse:29.30317
# [734]	validation_0-rmse:59.52739	validation_1-rmse:29.30359
# [735]	validation_0-rmse:59.52735	validation_1-rmse:29.30348
# [736]	validation_0-rmse:59.52717	validation_1-rmse:29.30398
# [737]	validation_0-rmse:59.52713	validation_1-rmse:29.30335
# [738]	validation_0-rmse:59.52695	validation_1-rmse:29.30384
# [739]	validation_0-rmse:59.52677	validation_1-rmse:29.30424
# [740]	validation_0-rmse:59.52675	validation_1-rmse:29.30448
# [741]	validation_0-rmse:59.52662	validation_1-rmse:29.30338
# [742]	validation_0-rmse:59.52659	validation_1-rmse:29.30323
# [743]	validation_0-rmse:59.52657	validation_1-rmse:29.30347
# [744]	validation_0-rmse:59.52644	validation_1-rmse:29.30240
# [745]	validation_0-rmse:59.52642	validation_1-rmse:29.30265
# [746]	validation_0-rmse:59.52630	validation_1-rmse:29.30161
# [747]	validation_0-rmse:59.52617	validation_1-rmse:29.30045
# [748]	validation_0-rmse:59.52615	validation_1-rmse:29.30071
# [749]	validation_0-rmse:59.52603	validation_1-rmse:29.29971
# [750]	validation_0-rmse:59.52600	validation_1-rmse:29.29952
# [751]	validation_0-rmse:59.52599	validation_1-rmse:29.29979
# [752]	validation_0-rmse:59.52587	validation_1-rmse:29.29868
# [753]	validation_0-rmse:59.52585	validation_1-rmse:29.29895
# [754]	validation_0-rmse:59.52573	validation_1-rmse:29.29799
# [755]	validation_0-rmse:59.52561	validation_1-rmse:29.29705
# [756]	validation_0-rmse:59.52560	validation_1-rmse:29.29733
# [757]	validation_0-rmse:59.52548	validation_1-rmse:29.29628
# [758]	validation_0-rmse:59.52547	validation_1-rmse:29.29609
# [759]	validation_0-rmse:59.52543	validation_1-rmse:29.29573
# [760]	validation_0-rmse:59.52541	validation_1-rmse:29.29601
# [761]	validation_0-rmse:59.52539	validation_1-rmse:29.29630
# [762]	validation_0-rmse:59.52528	validation_1-rmse:29.29540
# [763]	validation_0-rmse:59.52527	validation_1-rmse:29.29569
# [764]	validation_0-rmse:59.52516	validation_1-rmse:29.29481
# [765]	validation_0-rmse:59.52514	validation_1-rmse:29.29510
# [766]	validation_0-rmse:59.52503	validation_1-rmse:29.29412
# [767]	validation_0-rmse:59.52499	validation_1-rmse:29.29381
# [768]	validation_0-rmse:59.52498	validation_1-rmse:29.29490
# [769]	validation_0-rmse:59.52496	validation_1-rmse:29.29597
# [770]	validation_0-rmse:59.52486	validation_1-rmse:29.29501
# [771]	validation_0-rmse:59.52482	validation_1-rmse:29.29468
# [772]	validation_0-rmse:59.52481	validation_1-rmse:29.29575
# [773]	validation_0-rmse:59.52479	validation_1-rmse:29.29682
# [774]	validation_0-rmse:59.52470	validation_1-rmse:29.29629
# [775]	validation_0-rmse:59.52468	validation_1-rmse:29.29735
# [776]	validation_0-rmse:59.52464	validation_1-rmse:29.29709
# [777]	validation_0-rmse:59.52463	validation_1-rmse:29.29815
# [778]	validation_0-rmse:59.52459	validation_1-rmse:29.29782
# [779]	validation_0-rmse:59.52458	validation_1-rmse:29.29887
# [780]	validation_0-rmse:59.52456	validation_1-rmse:29.29916
# [781]	validation_0-rmse:59.52447	validation_1-rmse:29.29868
# [782]	validation_0-rmse:59.52445	validation_1-rmse:29.29972
# [783]	validation_0-rmse:59.52442	validation_1-rmse:29.29940
# [784]	validation_0-rmse:59.52441	validation_1-rmse:29.30044
# [785]	validation_0-rmse:59.52437	validation_1-rmse:29.30091
# [786]	validation_0-rmse:59.52435	validation_1-rmse:29.30117
# [787]	validation_0-rmse:59.52433	validation_1-rmse:29.30219
# [788]	validation_0-rmse:59.52430	validation_1-rmse:29.30155
# [789]	validation_0-rmse:59.52427	validation_1-rmse:29.30124
# [790]	validation_0-rmse:59.52425	validation_1-rmse:29.30226
# [791]	validation_0-rmse:59.52422	validation_1-rmse:29.30273
# [792]	validation_0-rmse:59.52420	validation_1-rmse:29.30298
# [793]	validation_0-rmse:59.52419	validation_1-rmse:29.30398
# [794]	validation_0-rmse:59.52416	validation_1-rmse:29.30336
# [795]	validation_0-rmse:59.52415	validation_1-rmse:29.30435
# [796]	validation_0-rmse:59.52412	validation_1-rmse:29.30405
# [797]	validation_0-rmse:59.52411	validation_1-rmse:29.30504
# [798]	validation_0-rmse:59.52408	validation_1-rmse:29.30474
# [799]	validation_0-rmse:59.52407	validation_1-rmse:29.30573
# [800]	validation_0-rmse:59.52405	validation_1-rmse:29.30596
# [801]	validation_0-rmse:59.52404	validation_1-rmse:29.30579
# [802]	validation_0-rmse:59.52402	validation_1-rmse:29.30520
# [803]	validation_0-rmse:59.52401	validation_1-rmse:29.30617
# [804]	validation_0-rmse:59.52400	validation_1-rmse:29.30601
# [805]	validation_0-rmse:59.52397	validation_1-rmse:29.30572
# [806]	validation_0-rmse:59.52396	validation_1-rmse:29.30669
# [807]	validation_0-rmse:59.52392	validation_1-rmse:29.30641
# [808]	validation_0-rmse:59.52391	validation_1-rmse:29.30738
# [809]	validation_0-rmse:59.52388	validation_1-rmse:29.30710
# [810]	validation_0-rmse:59.52387	validation_1-rmse:29.30806
# [811]	validation_0-rmse:59.52386	validation_1-rmse:29.30790
# [812]	validation_0-rmse:59.52386	validation_1-rmse:29.30774
# [813]	validation_0-rmse:59.52383	validation_1-rmse:29.30717
# [814]	validation_0-rmse:59.52382	validation_1-rmse:29.30813
# [815]	validation_0-rmse:59.52381	validation_1-rmse:29.30797
# [816]	validation_0-rmse:59.52379	validation_1-rmse:29.30750
# [817]	validation_0-rmse:59.52376	validation_1-rmse:29.30732
# [818]	validation_0-rmse:59.52375	validation_1-rmse:29.30829
# [819]	validation_0-rmse:59.52373	validation_1-rmse:29.30773
# [820]	validation_0-rmse:59.52372	validation_1-rmse:29.30869
# [821]	validation_0-rmse:59.52369	validation_1-rmse:29.30814
# [822]	validation_0-rmse:59.52368	validation_1-rmse:29.30909
# [823]	validation_0-rmse:59.52366	validation_1-rmse:29.30864
# [824]	validation_0-rmse:59.52363	validation_1-rmse:29.30847
# [825]	validation_0-rmse:59.52362	validation_1-rmse:29.30941
# [826]	validation_0-rmse:59.52361	validation_1-rmse:29.31035
# [827]	validation_0-rmse:59.52359	validation_1-rmse:29.30982
# [828]	validation_0-rmse:59.52358	validation_1-rmse:29.31075
# [829]	validation_0-rmse:59.52355	validation_1-rmse:29.31058
# [830]	validation_0-rmse:59.52353	validation_1-rmse:29.31151
# [831]	validation_0-rmse:59.52352	validation_1-rmse:29.31243
# [832]	validation_0-rmse:59.52350	validation_1-rmse:29.31216
# [833]	validation_0-rmse:59.52349	validation_1-rmse:29.31308
# [834]	validation_0-rmse:59.52346	validation_1-rmse:29.31291
# [835]	validation_0-rmse:59.52345	validation_1-rmse:29.31382
# [836]	validation_0-rmse:59.52343	validation_1-rmse:29.31334
# [837]	validation_0-rmse:59.52341	validation_1-rmse:29.31425
# [838]	validation_0-rmse:59.52332	validation_1-rmse:29.31381
# [839]	validation_0-rmse:59.52331	validation_1-rmse:29.31471
# [840]	validation_0-rmse:59.52330	validation_1-rmse:29.31560
# [841]	validation_0-rmse:59.52329	validation_1-rmse:29.31545
# [842]	validation_0-rmse:59.52329	validation_1-rmse:29.31529
# [843]	validation_0-rmse:59.52319	validation_1-rmse:29.31486
# [844]	validation_0-rmse:59.52318	validation_1-rmse:29.31550
# [845]	validation_0-rmse:59.52317	validation_1-rmse:29.31567
# [846]	validation_0-rmse:59.52308	validation_1-rmse:29.31525
# [847]	validation_0-rmse:59.52307	validation_1-rmse:29.31614
# [848]	validation_0-rmse:59.52298	validation_1-rmse:29.31574
# [849]	validation_0-rmse:59.52297	validation_1-rmse:29.31663
# [850]	validation_0-rmse:59.52295	validation_1-rmse:29.31726
# [851]	validation_0-rmse:59.52287	validation_1-rmse:29.31686
# [852]	validation_0-rmse:59.52285	validation_1-rmse:29.31775
# [853]	validation_0-rmse:59.52284	validation_1-rmse:29.31838
# [854]	validation_0-rmse:59.52275	validation_1-rmse:29.31799
# [855]	validation_0-rmse:59.52274	validation_1-rmse:29.31887
# [856]	validation_0-rmse:59.52273	validation_1-rmse:29.31950
# [857]	validation_0-rmse:59.52273	validation_1-rmse:29.31936
# [858]	validation_0-rmse:59.52264	validation_1-rmse:29.31898
# [859]	validation_0-rmse:59.52263	validation_1-rmse:29.31960
# [860]	validation_0-rmse:59.52263	validation_1-rmse:29.31946
# [861]	validation_0-rmse:59.52254	validation_1-rmse:29.31909
# [862]	validation_0-rmse:59.52252	validation_1-rmse:29.31881
# [863]	validation_0-rmse:59.52250	validation_1-rmse:29.31969
# [864]	validation_0-rmse:59.52249	validation_1-rmse:29.32031
# [865]	validation_0-rmse:59.52248	validation_1-rmse:29.32119
# [866]	validation_0-rmse:59.52247	validation_1-rmse:29.32115
# [867]	validation_0-rmse:59.52245	validation_1-rmse:29.32111
# [868]	validation_0-rmse:59.52244	validation_1-rmse:29.32173
# [869]	validation_0-rmse:59.52243	validation_1-rmse:29.32169
# [870]	validation_0-rmse:59.52241	validation_1-rmse:29.32142
# [871]	validation_0-rmse:59.52240	validation_1-rmse:29.32203
# [872]	validation_0-rmse:59.52238	validation_1-rmse:29.32142
# [873]	validation_0-rmse:59.52237	validation_1-rmse:29.32230
# [874]	validation_0-rmse:59.52235	validation_1-rmse:29.32108
# [875]	validation_0-rmse:59.52232	validation_1-rmse:29.32101
# [876]	validation_0-rmse:59.52231	validation_1-rmse:29.32163
# [877]	validation_0-rmse:59.52230	validation_1-rmse:29.32159
# [878]	validation_0-rmse:59.52228	validation_1-rmse:29.32115
# [879]	validation_0-rmse:59.52225	validation_1-rmse:29.32108
# [880]	validation_0-rmse:59.52224	validation_1-rmse:29.32170
# [881]	validation_0-rmse:59.52223	validation_1-rmse:29.32180
# [882]	validation_0-rmse:59.52221	validation_1-rmse:29.32096
# [883]	validation_0-rmse:59.52220	validation_1-rmse:29.32106
# [884]	validation_0-rmse:59.52218	validation_1-rmse:29.31962
# [885]	validation_0-rmse:59.52217	validation_1-rmse:29.31972
# [886]	validation_0-rmse:59.52215	validation_1-rmse:29.31880
# [887]	validation_0-rmse:59.52215	validation_1-rmse:29.31942
# [888]	validation_0-rmse:59.52214	validation_1-rmse:29.31952
# [889]	validation_0-rmse:59.52211	validation_1-rmse:29.31802
# [890]	validation_0-rmse:59.52210	validation_1-rmse:29.31812
# [891]	validation_0-rmse:59.52208	validation_1-rmse:29.31785
# [892]	validation_0-rmse:59.52208	validation_1-rmse:29.31846
# [893]	validation_0-rmse:59.52205	validation_1-rmse:29.31840
# [894]	validation_0-rmse:59.52205	validation_1-rmse:29.32026
# [895]	validation_0-rmse:59.52204	validation_1-rmse:29.32036
# [896]	validation_0-rmse:59.52203	validation_1-rmse:29.32096
# [897]	validation_0-rmse:59.52202	validation_1-rmse:29.32106
# [898]	validation_0-rmse:59.52200	validation_1-rmse:29.32018
# [899]	validation_0-rmse:59.52199	validation_1-rmse:29.32028
# [900]	validation_0-rmse:59.52198	validation_1-rmse:29.32088
# [901]	validation_0-rmse:59.52197	validation_1-rmse:29.32097
# [902]	validation_0-rmse:59.52195	validation_1-rmse:29.31927
# [903]	validation_0-rmse:59.52194	validation_1-rmse:29.31937
# [904]	validation_0-rmse:59.52193	validation_1-rmse:29.31882
# [905]	validation_0-rmse:59.52192	validation_1-rmse:29.31942
# [906]	validation_0-rmse:59.52191	validation_1-rmse:29.31952
# [907]	validation_0-rmse:59.52188	validation_1-rmse:29.31904
# [908]	validation_0-rmse:59.52188	validation_1-rmse:29.32048
# [909]	validation_0-rmse:59.52187	validation_1-rmse:29.32058
# [910]	validation_0-rmse:59.52185	validation_1-rmse:29.31890
# [911]	validation_0-rmse:59.52184	validation_1-rmse:29.31900
# [912]	validation_0-rmse:59.52183	validation_1-rmse:29.32043
# [913]	validation_0-rmse:59.52182	validation_1-rmse:29.32052
# [914]	validation_0-rmse:59.52181	validation_1-rmse:29.31967
# [915]	validation_0-rmse:59.52180	validation_1-rmse:29.31976
# [916]	validation_0-rmse:59.52175	validation_1-rmse:29.32036
# [917]	validation_0-rmse:59.52174	validation_1-rmse:29.32095
# [918]	validation_0-rmse:59.52173	validation_1-rmse:29.32104
# [919]	validation_0-rmse:59.52168	validation_1-rmse:29.32246
# [920]	validation_0-rmse:59.52164	validation_1-rmse:29.32305
# [921]	validation_0-rmse:59.52163	validation_1-rmse:29.32313
# [922]	validation_0-rmse:59.52161	validation_1-rmse:29.32454
# [923]	validation_0-rmse:59.52160	validation_1-rmse:29.32463
# [924]	validation_0-rmse:59.52156	validation_1-rmse:29.32521
# [925]	validation_0-rmse:59.52154	validation_1-rmse:29.32660
# [926]	validation_0-rmse:59.52153	validation_1-rmse:29.32590
# [927]	validation_0-rmse:59.52151	validation_1-rmse:29.32521
# [928]	validation_0-rmse:59.52150	validation_1-rmse:29.32579
# [929]	validation_0-rmse:59.52148	validation_1-rmse:29.32503
# [930]	validation_0-rmse:59.52147	validation_1-rmse:29.32476
# [931]	validation_0-rmse:59.52146	validation_1-rmse:29.32615
# [932]	validation_0-rmse:59.52145	validation_1-rmse:29.32587
# [933]	validation_0-rmse:59.52140	validation_1-rmse:29.32645
# [934]	validation_0-rmse:59.52139	validation_1-rmse:29.32783
# [935]	validation_0-rmse:59.52136	validation_1-rmse:29.32778
# [936]	validation_0-rmse:59.52135	validation_1-rmse:29.32739
# [937]	validation_0-rmse:59.52133	validation_1-rmse:29.32741
# [938]	validation_0-rmse:59.52132	validation_1-rmse:29.32799
# [939]	validation_0-rmse:59.52131	validation_1-rmse:29.32760
# [940]	validation_0-rmse:59.52129	validation_1-rmse:29.32762
# [941]	validation_0-rmse:59.52127	validation_1-rmse:29.32594
# [942]	validation_0-rmse:59.52125	validation_1-rmse:29.32596
# [943]	validation_0-rmse:59.52124	validation_1-rmse:29.32558
# [944]	validation_0-rmse:59.52119	validation_1-rmse:29.32696
# [945]	validation_0-rmse:59.52118	validation_1-rmse:29.32689
# [946]	validation_0-rmse:59.52117	validation_1-rmse:29.32746
# [947]	validation_0-rmse:59.52116	validation_1-rmse:29.32708
# [948]	validation_0-rmse:59.52114	validation_1-rmse:29.32710
# [949]	validation_0-rmse:59.52113	validation_1-rmse:29.32673
# [950]	validation_0-rmse:59.52107	validation_1-rmse:29.32809
# [951]	validation_0-rmse:59.52104	validation_1-rmse:29.32812
# [952]	validation_0-rmse:59.52098	validation_1-rmse:29.32868
# [953]	validation_0-rmse:59.52097	validation_1-rmse:29.32831
# [954]	validation_0-rmse:59.52095	validation_1-rmse:29.32647
# [955]	validation_0-rmse:59.52094	validation_1-rmse:29.32644
# [956]	validation_0-rmse:59.52093	validation_1-rmse:29.32607
# [957]	validation_0-rmse:59.52087	validation_1-rmse:29.32743
# [958]	validation_0-rmse:59.52085	validation_1-rmse:29.32740
# [959]	validation_0-rmse:59.52085	validation_1-rmse:29.32704
# [960]	validation_0-rmse:59.52084	validation_1-rmse:29.32698
# [961]	validation_0-rmse:59.52082	validation_1-rmse:29.32833
# [962]	validation_0-rmse:59.52082	validation_1-rmse:29.32797
# [963]	validation_0-rmse:59.52081	validation_1-rmse:29.32853
# [964]	validation_0-rmse:59.52080	validation_1-rmse:29.32807
# [965]	validation_0-rmse:59.52080	validation_1-rmse:29.32979
# [966]	validation_0-rmse:59.52079	validation_1-rmse:29.33113
# [967]	validation_0-rmse:59.52078	validation_1-rmse:29.33066
# [968]	validation_0-rmse:59.52077	validation_1-rmse:29.33060
# [969]	validation_0-rmse:59.52076	validation_1-rmse:29.33015
# [970]	validation_0-rmse:59.52076	validation_1-rmse:29.33023
# [971]	validation_0-rmse:59.52075	validation_1-rmse:29.33017
# [972]	validation_0-rmse:59.52075	validation_1-rmse:29.33073
# [973]	validation_0-rmse:59.52074	validation_1-rmse:29.33027
# [974]	validation_0-rmse:59.52073	validation_1-rmse:29.33036
# [975]	validation_0-rmse:59.52072	validation_1-rmse:29.33030
# [976]	validation_0-rmse:59.52072	validation_1-rmse:29.33024
# [977]	validation_0-rmse:59.52071	validation_1-rmse:29.33033
# [978]	validation_0-rmse:59.52070	validation_1-rmse:29.33027
# [979]	validation_0-rmse:59.52070	validation_1-rmse:29.33030
# [980]	validation_0-rmse:59.52064	validation_1-rmse:29.33086
# [981]	validation_0-rmse:59.52063	validation_1-rmse:29.33042
# [982]	validation_0-rmse:59.52063	validation_1-rmse:29.33051
# [983]	validation_0-rmse:59.52061	validation_1-rmse:29.33123
# [984]	validation_0-rmse:59.52060	validation_1-rmse:29.33117
# [985]	validation_0-rmse:59.52059	validation_1-rmse:29.33073
# [986]	validation_0-rmse:59.52059	validation_1-rmse:29.33082
# [987]	validation_0-rmse:59.52057	validation_1-rmse:29.33082
# [988]	validation_0-rmse:59.52057	validation_1-rmse:29.33139
# [989]	validation_0-rmse:59.52056	validation_1-rmse:29.33097
# [990]	validation_0-rmse:59.52056	validation_1-rmse:29.33107
# [991]	validation_0-rmse:59.52054	validation_1-rmse:29.33107
# [992]	validation_0-rmse:59.52048	validation_1-rmse:29.33239
# [993]	validation_0-rmse:59.52048	validation_1-rmse:29.33197
# [994]	validation_0-rmse:59.52047	validation_1-rmse:29.33190
# [995]	validation_0-rmse:59.52046	validation_1-rmse:29.33203
# [996]	validation_0-rmse:59.52045	validation_1-rmse:29.33161
# [997]	validation_0-rmse:59.52045	validation_1-rmse:29.33154
# [998]	validation_0-rmse:59.52043	validation_1-rmse:29.33008
# [999]	validation_0-rmse:59.52042	validation_1-rmse:29.33021
# XGBRegressor(base_score=0.2, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %% [markdown]
# ## Model Evaluation

# %%
x_test.shape, y_test.shape
# Out:
# ((73, 7), (73,))

# %% [markdown]
# #### Mean Squared Error

# %%
#finding the rmse score for the model

y_pred = model.predict(x_test)
score = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'RMSE Score on test set: {score:0.2f}')
# Out:
# RMSE Score on test set: 29.33

# %% [markdown]
# #### WMAPE

# %%
# Reference: https://www.indeed.com/career-advice/career-development/weighted-mean-absolute-percentage-error

def wmape(actual, forecast):
    """Calculate Weighted Mean Absolute Percentage Error (WMAPE) with equal weights"""

    weights = np.abs(actual - forecast)
    numerator = np.sum(weights) * 100
    denominator = np.sum(np.abs(actual))

    return numerator/denominator

# %%
#using wmape value on our data
wmape_value = wmape(y_test, y_pred)
print("WMAPE: {:.2f}%".format(wmape_value))
# Out:
# WMAPE: 83.85%

# %% [markdown]
# This WMAPE is very high, so this model may not be the best choice for prediction.

# %% [markdown]
# ### Plot Model Performance

# %%
#define the variable y_train_fit
y_train_fit = model.predict(x_train)

# %%
# add the y_train and y_pred to x_train as 2 new columns 
x_test['pred'] = y_pred
x_test['claim'] = y_test
x_train['pred'] = y_train_fit
x_train['claim'] = y_train

plot_df = pd.concat([x_train, x_test])

plot_df
# Out:
#               phone size  generation  week_of_month  month  year  \
# weeks_monday
# 2021-08-02           128          12              1      8  2021
# 2021-08-09           128          12              2      8  2021
# 2021-08-16           128          12              3      8  2021
# 2021-08-23           128          12              4      8  2021
# 2021-08-30           128          12              5      8  2021
# ...                  ...         ...            ...    ...   ...
# 2023-02-13           128          14              2      2  2023
# 2023-02-27           256          14              4      2  2023
# 2023-02-27           256          14              4      2  2023
# 2023-02-27           256          14              4      2  2023
# 2023-02-27           256          14              4      2  2023
#
#               weeks_since_release  day       pred  claim
# weeks_monday
# 2021-08-02              37.428571    2  60.256199     14
# 2021-08-09              38.428571    9  59.283188     43
# 2021-08-16              39.428571   16  58.581730     57
# 2021-08-23              40.428571   23  60.025486     65
# 2021-08-30              41.428571   30  57.551960     59
# ...                           ...  ...        ...    ...
# 2023-02-13              21.428571   13  21.433643      4
# 2023-02-27              23.428571   27  27.143034     33
# 2023-02-27              23.428571   27  27.143034      2
# 2023-02-27              23.428571   27  27.143034     39
# 2023-02-27              23.428571   27  27.143034      1
#
# [1278 rows x 9 columns]

# %%
# plot the xgboost results for both the actual and predicted values, x-axis is the weeks_monday and y-axis is the claim and group_by each phone model. 
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x="weeks_since_release", y="claim", hue="generation", data=plot_df, ax=ax, style= "generation")
sns.lineplot(x="weeks_since_release", y="pred", hue="generation", data=plot_df, ax=ax, markers=True, dashes=True)
plt.legend(loc='upper left')
# add another legend to show that the dashes line is the actual value and the line is the predicted value
plt.show()

# %% [markdown]
# Now plot with grouping the phone generations together.

# %%
# group by the pred and claim by phone size, generation, week_of_month, month, year, weeks_since_release, do not aggregate the pred and claim columns
new_df = plot_df.groupby(['generation', 'week_of_month', 'month', 'year', 'weeks_since_release'])['pred', 'claim'].sum()
new_df = new_df.reset_index()
new_df
# Out:
# C:\Users\Rachel Montgomery\AppData\Local\Temp\ipykernel_6460\1420137929.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df = plot_df.groupby(['generation', 'week_of_month', 'month', 'year', 'weeks_since_release'])['pred', 'claim'].sum()
#     generation  week_of_month  month  year  weeks_since_release         pred  \
# 0           12              1      7  2021            33.428571  1019.176025
# 1           12              1      8  2021            37.428571  1210.619995
# 2           12              1      9  2021            42.428571  1326.381470
# 3           12              1     10  2021            46.428571  1892.107666
# 4           12              2      7  2021            34.428571  1046.775391
# ..         ...            ...    ...   ...                  ...          ...
# 72          14              4      1  2023            18.428571    38.795181
# 73          14              4      2  2023            23.428571   345.750854
# 74          14              4     11  2022            10.428571    24.234510
# 75          14              4     12  2022            14.428571    44.585087
# 76          14              5      1  2023            19.428571    63.145275
#
#     claim
# 0    1017
# 1    1212
# 2    1335
# 3    1895
# 4    1045
# ..    ...
# 72     57
# 73    467
# 74     23
# 75     44
# 76     54
#
# [77 rows x 7 columns]

# %%
# plot the xgboost results for both the actual and predicted values, x-axis is the weeks_since_release and y-axis is the claim and pred for each phone model
# the line is the actual value and the dashes line is the  predicted value 
# use the same dashed style for all the generations
palette = sns.color_palette("flare", as_cmap=True)

fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(x="weeks_since_release", y="claim", hue="generation", data=new_df, palette=palette, ax=ax, alpha=0.6)
sns.lineplot(x="weeks_since_release", y="pred", hue="generation", data=new_df, palette=palette, ax=ax, style= "generation", dashes=[(2, 2), (2, 2), (1, 1)], linewidth = 3)

# add another legend to show that the dashed line is the actual value and the solid line is the predicted value
ax.plot([],[], label='actual', color = 'black')
ax.plot([],[], linestyle='--', label='predicted', color = 'black')
# add a title to the plot
ax.set_title('RF Prediction for iPhone 12, 13 and 14 Claims as a Function of weeks_since_release')
# add a verticle line at x = 44 with a hight of 80
plt.vlines(x=44, ymin=1000, ymax=2900, color='green', linewidth=2)
plt.vlines(x=15, ymin=0, ymax=300, color='green', linewidth=2)

plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
#do feature importance
xgb.plot_importance(model)
# Out:
# <AxesSubplot: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>
